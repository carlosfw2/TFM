# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("../Wyscout/jugadoresLimpioConPosiciones.xlsx")

# %%
df.head()
# Out:
#           Jugador    Equipo Posicion  Edad      VM FinContrato Nacionalidad  \
# 0       J. Mvondo  Albacete       ED  22.0  800000  2021-06-30     Cameroon
# 1     Tomeu Nadal  Albacete      POR  31.0  800000  2021-06-30        Spain
# 2     Fran García  Albacete       LI  28.0  600000  2021-06-30        Spain
# 3   Diego Caballo  Albacete       LI  26.0  600000  2022-06-30        Spain
# 4  Eddy Silvestre  Albacete       MC  28.0  600000  2023-06-30        Spain
#
#          Pie Cedido  PartidosJugados  ...  GolesEvitados  GolesEvitados/90  \
# 0    derecho     no               10  ...           0.00             0.000
# 1    derecho     no               20  ...           2.32             0.109
# 2  izquierdo     no                8  ...           0.00             0.000
# 3  izquierdo     no               15  ...           0.00             0.000
# 4    derecho     no               16  ...           0.00             0.000
#
# ...

# %%
df2 = df.copy()

# %%
#Filtramos por posicion
df2 = df2[(df2.Posicion == "LI") & (df2.MinutosJugados >= 900)]
df2.shape
# Out:
# (24, 108)

# %%
print(df2.columns.to_list())
# Out:
# ['Jugador', 'Equipo', 'Posicion', 'Edad', 'VM', 'FinContrato', 'Nacionalidad', 'Pie', 'Cedido', 'PartidosJugados', 'MinutosJugados', 'Goles', 'xG', 'Asistencias', 'xA', 'Duelos/90', '%DuelosGanados', 'Altura', 'Peso', 'AccionesDefensivasRealizadas/90', 'Duelosdefensivos/90', '%DuelosDefensivosGanados', 'DuelosAereos90', '%DuelosAereosGanados', 'Entradas/90', 'PosesionConquistadaPorEntrada', 'TirosInterceptados/90', 'Interceptaciones/90', 'PosesionConquistadaPorIntercepcion', 'Faltas/90', 'TarjetasAmarillas', 'TarjetasAmarillas/90', 'TarjetasRojas', 'TarjetasRojas/90', 'AccionesAtaqueExitosas/90', 'Goles/90', 'GolesSinPenalti', 'GolesSinPenalti/90', 'xG/90', 'GolesCabeza', 'GolesCabeza/90', 'Remates', 'Remates/90', '%TirosAPorteria', '%GolesConvertidos', 'Asistencias/90', 'Centros/90', '%PrecisionCentros', 'CentrosAreaPequeña/90', 'Regates/90', '%RegatesRealizados', 'DuelosOfensivos/90', '%DuelosOfensivosGanados', 'ToquesAreaPenalti/90', 'CarrerasProgresion/90', 'Aceleraciones/90', 'P
# ...

# %%
#Columnas que vamos a ponderar
subdf2 = pd.DataFrame(df2,columns=['Jugador','%PrecisionCentros','%DuelosAereosGanados'
                            ,'%RegatesRealizados',
                'CarrerasProgresion/90','Interceptaciones/90','%DuelosDefensivosGanados'
                            ,'%PrecisionPases','PasesProgresivos/90',
                'xA/90','AccionesDefensivasRealizadas/90','PasesProfundidad/90']) #Varias columnas
subdf2.head()
# Out:
#                  Jugador  %PrecisionCentros  %DuelosAereosGanados  \
# 3          Diego Caballo              25.93                 64.52
# 27           José Carlos              35.71                 51.38
# 52         Sergio Akieme              40.54                 51.11
# 97   Alberto De La Bella              17.14                 54.00
# 142        Adrià Pedrosa              32.20                 52.00
#
#      %RegatesRealizados  CarrerasProgresion/90  Interceptaciones/90  \
# 3                 50.00                   1.00                 4.53
# 27                68.75                   0.73                 5.60
# 52                76.00                   1.98                 5.61
# 97                60.00                   0.97                 4.89
# 142               50.00                   2.66                 4.86
#
#      %DuelosDefensivosGanados  %PrecisionPases  PasesProgresivos/90  xA/90  \
# 3                       56.07            71.38                 9.53   0.05
# ...

# %%
subdf2.describe()
# Out:
#        %PrecisionCentros  %DuelosAereosGanados  %RegatesRealizados  \
# count          24.000000             24.000000           24.000000
# mean           32.555417             54.294583           61.807500
# std             9.741699             10.931914            9.545227
# min            16.670000             32.000000           50.000000
# 25%            25.912500             49.597500           52.492500
# 50%            32.765000             53.665000           60.000000
# 75%            38.485000             61.470000           68.322500
# max            52.730000             76.060000           81.480000
#
#        CarrerasProgresion/90  Interceptaciones/90  %DuelosDefensivosGanados  \
# count              24.000000            24.000000                 24.000000
# mean                1.439583             4.775417                 58.512500
# std                 0.843922             0.861929                  5.295303
# ...

# %%
#Añadimos las columnas calculadas que queramos
#subdf2['xG/RemateContra'] = df2.apply(lambda row: row['xGEnContra']/row['RematesContra'], axis=1).round(2)

# %%
#Normalizamos cada columna por el mayor y damos el valor de la ponderizacion
subdf2['%PrecisionCentros'] = ((subdf2['%PrecisionCentros']/subdf2['%PrecisionCentros'].max())*1.4).round(2)
subdf2['%DuelosAereosGanados'] = ((subdf2['%DuelosAereosGanados']/subdf2['%DuelosAereosGanados'].max())*1.5).round(2)
subdf2['%RegatesRealizados'] = ((subdf2['%RegatesRealizados']/subdf2['%RegatesRealizados'].max())*1.5).round(2)
subdf2['CarrerasProgresion/90'] = ((subdf2['CarrerasProgresion/90']/subdf2['CarrerasProgresion/90'].max())*2).round(2)
subdf2['Interceptaciones/90'] = ((subdf2['Interceptaciones/90']/subdf2['Interceptaciones/90'].max())*1.5).round(2)
subdf2['%DuelosDefensivosGanados'] = ((subdf2['%DuelosDefensivosGanados']/subdf2['%DuelosDefensivosGanados'].max())*2).round(2)
subdf2['%PrecisionPases'] = ((subdf2['%PrecisionPases']/subdf2['%PrecisionPases'].max())*1.3).round(2)
subdf2['PasesProgresivos/90'] = ((subdf2['PasesProgresivos/90']/subdf2['PasesProgresivos/90'].max())*1.7).round(2)
subdf2['xA/90'] = ((subdf2['xA/90']/subdf2['xA/90'].max())*1.5).round(2)
subdf2['AccionesDefensivasRealizadas/90'] = ((subdf2['AccionesDefensivasRealizadas/90']/subdf2['AccionesDefensivasRealizadas/90'].max())*2).round(2)
subdf2['PasesProfundidad/90'] = ((subdf2['PasesProfundidad/90']/subdf2['PasesProfundidad/90'].max())*2).round(2)
subdf2.head()
# Out:
#                  Jugador  %PrecisionCentros  %DuelosAereosGanados  \
# 3          Diego Caballo               0.69                  1.27
# 27           José Carlos               0.95                  1.01
# 52         Sergio Akieme               1.08                  1.01
# 97   Alberto De La Bella               0.46                  1.06
# 142        Adrià Pedrosa               0.85                  1.03
#
#      %RegatesRealizados  CarrerasProgresion/90  Interceptaciones/90  \
# 3                  0.92                   0.55                 1.05
# 27                 1.27                   0.40                 1.29
# 52                 1.40                   1.08                 1.29
# 97                 1.10                   0.53                 1.13
# 142                0.92                   1.45                 1.12
#
#      %DuelosDefensivosGanados  %PrecisionPases  PasesProgresivos/90  xA/90  \
# 3                        1.66             1.12                 1.19   0.36
# ...

# %%
#Sumamos las columnas desde la ultima posicion hasta la que queramos para sacar la puntuacion
subdf2['PuntuacionTotal']= subdf2.iloc[:, -11:-1].sum(axis=1)
subdf2 = subdf2.sort_values(by='PuntuacionTotal', ascending=False)
subdf2.head()
# Out:
#           Jugador  %PrecisionCentros  %DuelosAereosGanados  \
# 550   Iñaki Sáenz               1.00                  1.50
# 468     P. Cornud               0.83                  1.01
# 444  Carlos Nieto               1.17                  1.14
# 525    Álex Muñoz               1.40                  1.22
# 497   Saúl García               0.88                  1.34
#
#      %RegatesRealizados  CarrerasProgresion/90  Interceptaciones/90  \
# 550                0.94                   1.22                 0.88
# 468                1.10                   1.10                 1.29
# 444                1.31                   1.23                 1.17
# 525                1.10                   1.28                 1.29
# 497                1.50                   0.71                 1.02
#
#      %DuelosDefensivosGanados  %PrecisionPases  PasesProgresivos/90  xA/90  \
# 550                      1.80             1.06                 1.63   1.50
# ...

# %%
#Quitamos las columnas del dataframe original para añadir las del dataframe con la puntuacion
df2SinColumnas = df2.drop(['%PrecisionCentros','%DuelosAereosGanados'
                            ,'%RegatesRealizados',
                'CarrerasProgresion/90','Interceptaciones/90','%DuelosDefensivosGanados'
                            ,'%PrecisionPases','PasesProgresivos/90',
                'xA/90','AccionesDefensivasRealizadas/90','PasesProfundidad/90'], axis=1)
df2SinColumnas.head()
# Out:
#                  Jugador     Equipo Posicion  Edad       VM FinContrato  \
# 3          Diego Caballo   Albacete       LI  26.0   600000  2022-06-30
# 27           José Carlos   Alcorcón       LI  24.0   600000  2022-06-30
# 52         Sergio Akieme    Almería       LI  23.0  3000000  2023-06-30
# 97   Alberto De La Bella  Cartagena       LI  35.0   300000  2021-06-30
# 142        Adrià Pedrosa   Espanyol       LI  22.0  5000000  2023-06-30
#
#     Nacionalidad        Pie Cedido  PartidosJugados  ...  GolesEvitados  \
# 3          Spain  izquierdo     no               15  ...            0.0
# 27         Spain  izquierdo     no               19  ...            0.0
# 52         Spain  izquierdo     si               15  ...            0.0
# 97         Spain  izquierdo     si               16  ...            0.0
# 142        Spain  izquierdo     no               14  ...            0.0
#
#      GolesEvitados/90  Salidas/90  DuelosAereosPortero90  TirosLibres/90  \
# ...

# %%
#Creamos dataframe con aspectos basicos del jugador para añadir al dataframe final
dfFinal = pd.merge(subdf2,df2SinColumnas, on='Jugador', how='left')
dfFinal.head()
# Out:
#         Jugador  %PrecisionCentros  %DuelosAereosGanados  %RegatesRealizados  \
# 0   Iñaki Sáenz               1.00                  1.50                0.94
# 1     P. Cornud               0.83                  1.01                1.10
# 2  Carlos Nieto               1.17                  1.14                1.31
# 3    Álex Muñoz               1.40                  1.22                1.10
# 4   Saúl García               0.88                  1.34                1.50
#
#    CarrerasProgresion/90  Interceptaciones/90  %DuelosDefensivosGanados  \
# 0                   1.22                 0.88                      1.80
# 1                   1.10                 1.29                      1.90
# 2                   1.23                 1.17                      1.90
# 3                   1.28                 1.29                      1.68
# 4                   0.71                 1.02                      2.00
#
#    %PrecisionPases  PasesProgresivos/90  xA/90  ...  GolesEvitados  \
# ...

# %%
dfFinal.to_csv("puntuacionLateralIzquierdo.csv", encoding="utf-8-sig")
