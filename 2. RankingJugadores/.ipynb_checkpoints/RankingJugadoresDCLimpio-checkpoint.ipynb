# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("../Wyscout/jugadoresLimpioConPosiciones.xlsx")

# %%
df.head()
# Out:
#           Jugador    Equipo Posicion  Edad      VM FinContrato Nacionalidad  \
# 0       J. Mvondo  Albacete       ED  22.0  800000  2021-06-30     Cameroon
# 1     Tomeu Nadal  Albacete      POR  31.0  800000  2021-06-30        Spain
# 2     Fran García  Albacete       LI  28.0  600000  2021-06-30        Spain
# 3   Diego Caballo  Albacete       LI  26.0  600000  2022-06-30        Spain
# 4  Eddy Silvestre  Albacete       MC  28.0  600000  2023-06-30        Spain
#
#          Pie Cedido  PartidosJugados  ...  GolesEvitados  GolesEvitados/90  \
# 0    derecho     no               10  ...           0.00             0.000
# 1    derecho     no               20  ...           2.32             0.109
# 2  izquierdo     no                8  ...           0.00             0.000
# 3  izquierdo     no               15  ...           0.00             0.000
# 4    derecho     no               16  ...           0.00             0.000
#
#    Salidas/90  DuelosAereosPortero90  TirosLibres/90  TirosLibresDirecto/90  \
# 0         0.0                   0.00            0.00                   0.00
# 1         0.8                   0.19            0.00                   0.00
# 2         0.0                   0.00            0.35                   0.00
# 3         0.0                   0.00            1.27                   0.27
# 4         0.0                   0.00            0.00                   0.00
#
#    %TirosLibresDirecto  Córneres/90  Penaltis  %PenaltisConvertidos
# 0                  0.0         0.00         0                   0.0
# 1                  0.0         0.00         0                   0.0
# 2                  0.0         0.53         0                   0.0
# 3                 25.0         0.73         0                   0.0
# 4                  0.0         0.00         0                   0.0
#
# [5 rows x 108 columns]

# %%
df2 = df.copy()

# %%
#Filtramos por posicion
df2 = df2[(df2.Posicion == "DC") & (df2.MinutosJugados >= 900)]
df2.shape
# Out:
# (30, 108)

# %%
print(df2.columns.to_list())
# Out:
# ['Jugador', 'Equipo', 'Posicion', 'Edad', 'VM', 'FinContrato', 'Nacionalidad', 'Pie', 'Cedido', 'PartidosJugados', 'MinutosJugados', 'Goles', 'xG', 'Asistencias', 'xA', 'Duelos/90', '%DuelosGanados', 'Altura', 'Peso', 'AccionesDefensivasRealizadas/90', 'Duelosdefensivos/90', '%DuelosDefensivosGanados', 'DuelosAereos90', '%DuelosAereosGanados', 'Entradas/90', 'PosesionConquistadaPorEntrada', 'TirosInterceptados/90', 'Interceptaciones/90', 'PosesionConquistadaPorIntercepcion', 'Faltas/90', 'TarjetasAmarillas', 'TarjetasAmarillas/90', 'TarjetasRojas', 'TarjetasRojas/90', 'AccionesAtaqueExitosas/90', 'Goles/90', 'GolesSinPenalti', 'GolesSinPenalti/90', 'xG/90', 'GolesCabeza', 'GolesCabeza/90', 'Remates', 'Remates/90', '%TirosAPorteria', '%GolesConvertidos', 'Asistencias/90', 'Centros/90', '%PrecisionCentros', 'CentrosAreaPequeña/90', 'Regates/90', '%RegatesRealizados', 'DuelosOfensivos/90', '%DuelosOfensivosGanados', 'ToquesAreaPenalti/90', 'CarrerasProgresion/90', 'Aceleraciones/90', 'PasesRecibidos/90', 'PasesLargosRecibidos/90', 'FaltasRecibidas/90', 'Pases/90', '%PrecisionPases', 'PasesHaciaDelante/90', '%PrecisionPasesHaciaAdelante', 'PasesHaciaAtras/90', '%PrecisionPasesHaciaAtras', 'PasesLaterales/90', '%PrecisionPasesLaterales', 'PasesCorMed90', '%PrecisionPasesCorMed', 'PasesLargos/90', '%PrecisionPasesLargos', 'LongitudMediaPases', 'LongitudMediaPasesLargos', 'xA/90', 'Asistencias/90.1', 'SegundasAsistencias/90', 'TercerasAsistencias/90', 'Desmarques/90', '%PrecisionDesmarques', 'JugadasClaves/90', 'PasesUltimoTercio/90', '%PrecisionPasesUltimoTercio', 'PasesAreaPenalti/90', '%PasesAreaPequeña', 'PasesProfundidad/90', '%PrecisionPasesProfundidad', 'AtaquesProfundidad/90', 'CentrosUltimoTercio/90', 'PasesProgresivos/90', '%PrecisionPasesProgresivos', 'GolesRecibidos', 'GolesRecibidos/90', 'RematesContra', 'RematesContra/90', 'PorteriasImbatidas', '%Paradas', 'xGEnContra', 'xGEnContra/90', 'GolesEvitados', 'GolesEvitados/90', 'Salidas/90', 'DuelosAereosPortero90', 'TirosLibres/90', 'TirosLibresDirecto/90', '%TirosLibresDirecto', 'Córneres/90', 'Penaltis', '%PenaltisConvertidos']

# %%
#Columnas que vamos a ponderar
subdf2 = pd.DataFrame(df2,columns=['Jugador','xG/90','Remates/90','Remates'
                            ,'xA/90','Desmarques/90'
                            ,'%RegatesRealizados','%DuelosOfensivosGanados'
                            ,'AccionesAtaqueExitosas/90','Regates/90'
                            ,'CarrerasProgresion/90'
                            ,'GolesSinPenalti/90','xG','%DuelosAereosGanados'
                            ,]) #Varias columnas
subdf2.head()
# Out:
#            Jugador  xG/90  Remates/90  Remates  xA/90  Desmarques/90  \
# 9      Manu Fuster   0.08        0.62        9   0.03           0.83
# 22  Alfredo Ortuño   0.29        1.79       24   0.08           0.82
# 23      R. Zozulya   0.14        1.00       12   0.04           0.08
# 29   Óscar Arribas   0.20        1.43       22   0.13           0.20
# 44       Marc Gual   0.37        2.39       31   0.02           0.46
#
#     %RegatesRealizados  %DuelosOfensivosGanados  AccionesAtaqueExitosas/90  \
# 9                46.55                    43.86                       2.82
# 22               46.81                    31.40                       2.61
# 23               62.50                    30.30                       0.83
# 29               38.98                    35.47                       2.28
# 44               33.33                    23.81                       2.69
#
#     Regates/90  CarrerasProgresion/90  GolesSinPenalti/90    xG  \
# 9         3.99                   0.90                0.00  1.21
# 22        3.50                   1.19                0.00  3.90
# 23        0.67                   0.33                0.00  1.62
# 29        3.85                   1.04                0.07  3.00
# 44        4.16                   0.54                0.15  4.78
#
#     %DuelosAereosGanados
# 9                  22.22
# 22                 35.59
# 23                 43.44
# 29                 34.82
# 44                 25.00

# %%
#Añadimos las columnas calculadas que queramos
subdf2['xG/Remate'] = df2.apply(lambda row: row['xG']/row['Remates'], axis=1).round(2)

# %%
subdf2 = subdf2.drop(['xG','Remates','Remates/90'], axis=1)

# %%
#Normalizamos cada columna por el mayor y damos el valor de la ponderizacion
subdf2['xG/Remate'] = ((subdf2['xG/Remate']/subdf2['xG/Remate'].max())*3).round(2)
subdf2['xG/90'] = ((subdf2['xG/90']/subdf2['xG/90'].max())*3).round(2)
subdf2['xA/90'] = ((subdf2['xA/90']/subdf2['xA/90'].max())*1.5).round(2)
subdf2['Desmarques/90'] = ((subdf2['Desmarques/90']/subdf2['Desmarques/90'].max())*1.5).round(2)
subdf2['%RegatesRealizados'] = ((subdf2['%RegatesRealizados']/subdf2['%RegatesRealizados'].max())*1.8).round(2)
subdf2['%DuelosOfensivosGanados'] = ((subdf2['%DuelosOfensivosGanados']/subdf2['%DuelosOfensivosGanados'].max())*1.8).round(2)
subdf2['AccionesAtaqueExitosas/90'] = ((subdf2['AccionesAtaqueExitosas/90']/subdf2['AccionesAtaqueExitosas/90'].max())*2).round(2)
subdf2['Regates/90'] = ((subdf2['Regates/90']/subdf2['Regates/90'].max())*1.2).round(2)
subdf2['CarrerasProgresion/90'] = ((subdf2['CarrerasProgresion/90']/subdf2['CarrerasProgresion/90'].max())*1.2).round(2)
subdf2['GolesSinPenalti/90'] = ((subdf2['GolesSinPenalti/90']/subdf2['GolesSinPenalti/90'].max())*2).round(2)
subdf2['%DuelosAereosGanados'] = ((subdf2['%DuelosAereosGanados']/subdf2['%DuelosAereosGanados'].max())*1.5).round(2)

subdf2.head()
# Out:
#            Jugador  xG/90  xA/90  Desmarques/90  %RegatesRealizados  \
# 9      Manu Fuster   0.40   0.24           0.43                1.17
# 22  Alfredo Ortuño   1.45   0.63           0.43                1.17
# 23      R. Zozulya   0.70   0.32           0.04                1.57
# 29   Óscar Arribas   1.00   1.03           0.10                0.98
# 44       Marc Gual   1.85   0.16           0.24                0.83
#
#     %DuelosOfensivosGanados  AccionesAtaqueExitosas/90  Regates/90  \
# 9                      1.48                       1.26        0.93
# 22                     1.06                       1.16        0.82
# 23                     1.02                       0.37        0.16
# 29                     1.19                       1.02        0.90
# 44                     0.80                       1.20        0.97
#
#     CarrerasProgresion/90  GolesSinPenalti/90  %DuelosAereosGanados  xG/Remate
# 9                    0.46                0.00                  0.64       1.44
# 22                   0.60                0.00                  1.03       1.78
# 23                   0.17                0.00                  1.26       1.56
# 29                   0.53                0.27                  1.01       1.56
# 44                   0.27                0.58                  0.72       1.67

# %%
#Sumamos las columnas desde la ultima posicion hasta la que queramos para sacar la puntuacion
subdf2['PuntuacionTotal']= subdf2.iloc[:, -11:-1].sum(axis=1)
subdf2 = subdf2.sort_values(by='PuntuacionTotal', ascending=False)
subdf2.head()
# Out:
#             Jugador  xG/90  xA/90  Desmarques/90  %RegatesRealizados  \
# 158   Raúl de Tomás   2.45   0.95           0.28                1.09
# 417        N. Leiva   0.80   1.34           0.66                1.50
# 323  Dani Rodríguez   1.60   0.63           0.50                1.43
# 96   Elady Zorrilla   1.50   0.63           0.32                1.28
# 72         U. Sadiq   3.00   0.39           0.20                0.90
#
#      %DuelosOfensivosGanados  AccionesAtaqueExitosas/90  Regates/90  \
# 158                     1.26                       1.51        0.86
# 417                     1.47                       2.00        1.13
# 323                     1.42                       1.97        0.97
# 96                      1.32                       1.72        1.20
# 72                      1.02                       1.38        1.01
#
#      CarrerasProgresion/90  GolesSinPenalti/90  %DuelosAereosGanados  \
# 158                   0.22                1.85                  1.28
# 417                   0.99                0.85                  0.92
# 323                   1.20                1.00                  0.74
# 96                    0.90                1.42                  1.13
# 72                    0.65                2.00                  0.79
#
#      xG/Remate  PuntuacionTotal
# 158       2.11            11.75
# 417       1.22            11.66
# 323       2.33            11.46
# 96        2.11            11.42
# 72        3.00            11.34

# %%
#Quitamos las columnas del dataframe original para añadir las del dataframe con la puntuacion
df2SinColumnas = df2.drop(['xG/90'
                            ,'xA/90','Desmarques/90'
                            ,'%RegatesRealizados','%DuelosOfensivosGanados'
                            ,'AccionesAtaqueExitosas/90','Regates/90'
                            ,'CarrerasProgresion/90'
                            ,'GolesSinPenalti/90','%DuelosAereosGanados'
                            ,'%GolesConvertidos'], axis=1)
df2SinColumnas.head()
# Out:
#            Jugador    Equipo Posicion  Edad      VM FinContrato Nacionalidad  \
# 9      Manu Fuster  Albacete       DC  23.0  500000  2023-06-30        Spain
# 22  Alfredo Ortuño  Albacete       DC  29.0  800000  2021-06-30        Spain
# 23      R. Zozulya  Albacete       DC  31.0  700000  2021-06-30      Ukraine
# 29   Óscar Arribas  Alcorcón       DC  22.0  500000  2022-06-30        Spain
# 44       Marc Gual  Alcorcón       DC  24.0  800000  2022-06-30        Spain
#
#           Pie Cedido  PartidosJugados  ...  GolesEvitados  GolesEvitados/90  \
# 9     derecho     no               18  ...            0.0               0.0
# 22  izquierdo     no               18  ...            0.0               0.0
# 23    derecho     no               18  ...            0.0               0.0
# 29    derecho     no               20  ...            0.0               0.0
# 44    derecho     no               17  ...            0.0               0.0
#
#     Salidas/90  DuelosAereosPortero90  TirosLibres/90  TirosLibresDirecto/90  \
# 9          0.0                    0.0            0.07                   0.00
# 22         0.0                    0.0            0.00                   0.00
# 23         0.0                    0.0            0.00                   0.00
# 29         0.0                    0.0            0.98                   0.33
# 44         0.0                    0.0            0.00                   0.00
#
#     %TirosLibresDirecto  Córneres/90  Penaltis  %PenaltisConvertidos
# 9                   0.0         0.07         0                 0.000
# 22                  0.0         0.00         2                50.000
# 23                  0.0         0.00         1               100.000
# 29                 40.0         1.43         0                 0.000
# 44                  0.0         0.00         3                66.667
#
# [5 rows x 97 columns]

# %%
#Creamos dataframe con aspectos basicos del jugador para añadir al dataframe final
dfFinal = pd.merge(subdf2,df2SinColumnas, on='Jugador', how='left')
dfFinal.head()
# Out:
#           Jugador  xG/90  xA/90  Desmarques/90  %RegatesRealizados  \
# 0   Raúl de Tomás   2.45   0.95           0.28                1.09
# 1        N. Leiva   0.80   1.34           0.66                1.50
# 2  Dani Rodríguez   1.60   0.63           0.50                1.43
# 3  Elady Zorrilla   1.50   0.63           0.32                1.28
# 4        U. Sadiq   3.00   0.39           0.20                0.90
#
#    %DuelosOfensivosGanados  AccionesAtaqueExitosas/90  Regates/90  \
# 0                     1.26                       1.51        0.86
# 1                     1.47                       2.00        1.13
# 2                     1.42                       1.97        0.97
# 3                     1.32                       1.72        1.20
# 4                     1.02                       1.38        1.01
#
#    CarrerasProgresion/90  GolesSinPenalti/90  ...  GolesEvitados  \
# 0                   0.22                1.85  ...            0.0
# 1                   0.99                0.85  ...            0.0
# 2                   1.20                1.00  ...            0.0
# 3                   0.90                1.42  ...            0.0
# 4                   0.65                2.00  ...            0.0
#
#    GolesEvitados/90  Salidas/90 DuelosAereosPortero90 TirosLibres/90  \
# 0               0.0         0.0                   0.0           0.16
# 1               0.0         0.0                   0.0           0.22
# 2               0.0         0.0                   0.0           0.26
# 3               0.0         0.0                   0.0           0.00
# 4               0.0         0.0                   0.0           0.00
#
#    TirosLibresDirecto/90  %TirosLibresDirecto Córneres/90 Penaltis  \
# 0                   0.11                 50.0        0.05        3
# 1                   0.00                  0.0        0.45        0
# 2                   0.00                  0.0        0.32        3
# 3                   0.00                  0.0        0.06        0
# 4                   0.00                  0.0        0.00        1
#
#   %PenaltisConvertidos
# 0              100.000
# 1                0.000
# 2               66.667
# 3                0.000
# 4              100.000
#
# [5 rows x 109 columns]

# %%
dfFinal.to_csv("puntuacionDelanteros.csv", encoding="utf-8-sig")
